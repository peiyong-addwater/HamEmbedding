# %%
# !pip install pennylane pennylane-lightning pennylane-lightning[gpu] --upgrade
# !pip install --upgrade "jax[cuda11_pip]" -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# Out:
# Requirement already satisfied: pennylane in /usr/local/lib/python3.10/dist-packages (0.34.0)
# Requirement already satisfied: pennylane-lightning in /usr/local/lib/python3.10/dist-packages (0.34.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.11.4)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from pennylane) (3.2.1)
# Requirement already satisfied: rustworkx in /usr/local/lib/python3.10/dist-packages (from pennylane) (0.14.0)
# Requirement already satisfied: autograd in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.6.2)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from pennylane) (0.10.2)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.4.4)
# Requirement already satisfied: semantic-version>=2.7 in /usr/local/lib/python3.10/dist-packages (from pennylane) (2.10.0)
# Requirement already satisfied: autoray>=0.6.1 in /usr/local/lib/python3.10/dist-packages (from pennylane) (0.6.8)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from pennylane) (5.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pennylane) (2.31.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pennylane) (4.5.0)
# Requirement already satisfied: pennylane-lightning-gpu in /usr/local/lib/python3.10/dist-packages (from pennylane-lightning) (0.34.0)
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.10/dist-packages (from autograd->pennylane) (0.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (2023.11.17)
# Looking in links: https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# Requirement already satisfied: jax[cuda11_pip] in /usr/local/lib/python3.10/dist-packages (0.4.23)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax[cuda11_pip]) (0.2.0)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.10/dist-packages (from jax[cuda11_pip]) (1.23.5)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax[cuda11_pip]) (3.3.0)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from jax[cuda11_pip]) (1.11.4)
# Collecting jaxlib==0.4.23+cuda11.cudnn86 (from jax[cuda11_pip])
#   Downloading https://storage.googleapis.com/jax-releases/cuda11/jaxlib-0.4.23%2Bcuda11.cudnn86-cp310-cp310-manylinux2014_x86_64.whl (129.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.0/129.0 MB 8.4 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu11>=11.11 (from jax[cuda11_pip])
#   Downloading nvidia_cublas_cu11-11.11.3.6-py3-none-manylinux1_x86_64.whl (417.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 2.8 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu11>=11.8 (from jax[cuda11_pip])
#   Downloading nvidia_cuda_cupti_cu11-11.8.87-py3-none-manylinux1_x86_64.whl (13.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 80.0 MB/s eta 0:00:00
# Collecting nvidia-cuda-nvcc-cu11>=11.8 (from jax[cuda11_pip])
#   Downloading nvidia_cuda_nvcc_cu11-11.8.89-py3-none-manylinux1_x86_64.whl (19.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.5/19.5 MB 8.6 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu11>=11.8 (from jax[cuda11_pip])
#   Downloading nvidia_cuda_runtime_cu11-11.8.89-py3-none-manylinux1_x86_64.whl (875 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.6/875.6 kB 67.5 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu11>=8.8 (from jax[cuda11_pip])
#   Downloading nvidia_cudnn_cu11-8.9.6.50-py3-none-manylinux1_x86_64.whl (699.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 699.9/699.9 MB 2.3 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu11>=10.9 (from jax[cuda11_pip])
#   Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux1_x86_64.whl (168.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 9.7 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu11>=11.4 (from jax[cuda11_pip])
#   Downloading nvidia_cusolver_cu11-11.4.1.48-py3-none-manylinux1_x86_64.whl (128.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 MB 12.8 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu11>=11.7 (from jax[cuda11_pip])
#   Downloading nvidia_cusparse_cu11-11.7.5.86-py3-none-manylinux1_x86_64.whl (204.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.1/204.1 MB 3.7 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu11>=2.18.3 (from jax[cuda11_pip])
#   Downloading nvidia_nccl_cu11-2.19.3-py3-none-manylinux1_x86_64.whl (135.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.3/135.3 MB 5.2 MB/s eta 0:00:00
# Collecting nvidia-cuda-nvrtc-cu11 (from nvidia-cudnn-cu11>=8.8->jax[cuda11_pip])
#   Downloading nvidia_cuda_nvrtc_cu11-11.8.89-py3-none-manylinux1_x86_64.whl (23.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 57.2 MB/s eta 0:00:00
# Installing collected packages: nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-cufft-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-nvcc-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, nvidia-cusolver-cu11, nvidia-cudnn-cu11, jaxlib
#   Attempting uninstall: jaxlib
#     Found existing installation: jaxlib 0.4.23+cuda12.cudnn89
#     Uninstalling jaxlib-0.4.23+cuda12.cudnn89:
#       Successfully uninstalled jaxlib-0.4.23+cuda12.cudnn89
# Successfully installed jaxlib-0.4.23+cuda11.cudnn86 nvidia-cublas-cu11-11.11.3.6 nvidia-cuda-cupti-cu11-11.8.87 nvidia-cuda-nvcc-cu11-11.8.89 nvidia-cuda-nvrtc-cu11-11.8.89 nvidia-cuda-runtime-cu11-11.8.89 nvidia-cudnn-cu11-8.9.6.50 nvidia-cufft-cu11-10.9.0.58 nvidia-cusolver-cu11-11.4.1.48 nvidia-cusparse-cu11-11.7.5.86 nvidia-nccl-cu11-2.19.3

# %%
# Import packages
import matplotlib as mpl
import matplotlib.pyplot as plt
import sys
import numpy as np
#np.set_printoptions(threshold=sys.maxsize)
import pandas as pd
from sklearn import datasets
import seaborn as sns
import jax
import time
from tifffile import tifffile
import functools

from typing import List, Union, Tuple, Dict, Optional, Any
from typing import Callable

jax.config.update("jax_enable_x64", True)
#jax.config.update("jax_debug_nans", True)
import jax.numpy as jnp

import optax  # optimization using jax

import torch  # https://pytorch.org
import torchvision  # https://pytorch.org
#torch.set_printoptions(profile="full")
import pennylane as qml
import pennylane.numpy as pnp

import os, cv2, itertools # cv2 -- OpenCV
import shutil
import zipfile
# %matplotlib inline

from jax.lib import xla_bridge

def set_jax_platform():
    # Check if TPU is available
    try:
        tpu_backend = xla_bridge.get_backend('tpu')
        if tpu_backend and tpu_backend.device_count() > 0:
            # Set platform to TPU
            jax.config.update('jax_platform_name', 'tpu')
            print("Set platform to TPU")
            return
    except RuntimeError:
        pass  # No TPU found, move on to check for GPU

    # Check if GPU is available
    try:
      gpu_backend = xla_bridge.get_backend('gpu')
      if gpu_backend and gpu_backend.device_count() > 0:
          # Set platform to CUDA (GPU)
          jax.config.update('jax_platform_name', 'gpu')
          print("Set platform to GPU")
    except RuntimeError:
          # Set platform to CPU
          jax.config.update('jax_platform_name', 'cpu')
          print("Set platform to CPU")

# Call the function to set the platform
set_jax_platform()

sns.set()

seed = 1701
rng = np.random.default_rng(seed=seed)
prng = pnp.random.default_rng(seed=seed)
jrng_key = jax.random.PRNGKey(seed)
# Out:
# Set platform to GPU

# %% [markdown]
# # QCNN for the Scikit-Learn Digits Dataset Classification
#
# We will use the 8-class digit dataset (0, 1, 2, 3, 4, 5, 6, 7). QCNN structure follows [Generalization in QML from few training data](https://pennylane.ai/qml/demos/tutorial_learning_few_data/).

# %%
def convolutional_layer(weights, wires, skip_first_layer=True):
    """Adds a convolutional layer to a circuit.
    Args:
        weights (np.array): 1D array with 15 weights of the parametrized gates.
        wires (list[int]): Wires where the convolutional layer acts on.
        skip_first_layer (bool): Skips the first two U3 gates of a layer.
    """
    n_wires = len(wires)
    assert n_wires >= 3, "this circuit is too small!"

    for p in [0, 1]:
        for indx, w in enumerate(wires):
            if indx % 2 == p and indx < n_wires - 1:
                if indx % 2 == 0 and not skip_first_layer:
                    qml.U3(*weights[:3], wires=[w])
                    qml.U3(*weights[3:6], wires=[wires[indx + 1]])
                qml.IsingXX(weights[6], wires=[w, wires[indx + 1]])
                qml.IsingYY(weights[7], wires=[w, wires[indx + 1]])
                qml.IsingZZ(weights[8], wires=[w, wires[indx + 1]])
                qml.U3(*weights[9:12], wires=[w])
                qml.U3(*weights[12:], wires=[wires[indx + 1]])

def pooling_layer(weights, wires):
    """Adds a pooling layer to a circuit.
    Args:
        weights (np.array): Array with the weights of the conditional U3 gate.
        wires (list[int]): List of wires to apply the pooling layer on.
    """
    n_wires = len(wires)
    assert len(wires) >= 2, "this circuit is too small!"

    for indx, w in enumerate(wires):
        if indx % 2 == 1 and indx < n_wires:
            m_outcome = qml.measure(w)
            qml.cond(m_outcome, qml.U3)(*weights, wires=wires[indx - 1])

def conv_and_pooling(kernel_weights, n_wires, skip_first_layer=True):
    """Apply both the convolutional and pooling layer."""
    convolutional_layer(kernel_weights[:15], n_wires, skip_first_layer=skip_first_layer)
    pooling_layer(kernel_weights[15:], n_wires)


def dense_layer(weights, wires):
    """Apply an arbitrary unitary gate to a specified set of wires."""
    qml.ArbitraryUnitary(weights, wires)


num_wires = 6
device = qml.device("default.qubit", wires=num_wires)


@qml.qnode(device)
def conv_net(weights, last_layer_weights, features):
    """Define the QCNN circuit
    Args:
        weights (np.array): Parameters of the convolution and pool layers.
        last_layer_weights (np.array): Parameters of the last dense layer.
        features (np.array): Input data to be embedded using AmplitudEmbedding."""

    layers = weights.shape[1]
    wires = list(range(num_wires))

    # inputs the state input_state
    qml.AmplitudeEmbedding(features=features, wires=wires, pad_with=0.5)
    qml.Barrier(wires=wires, only_visual=True)

    # adds convolutional and pooling layers
    for j in range(layers):
        conv_and_pooling(weights[:, j], wires, skip_first_layer=(not j == 0))
        wires = wires[::2]
        qml.Barrier(wires=wires, only_visual=True)

    assert last_layer_weights.size == 4 ** (len(wires)) - 1, (
        "The size of the last layer weights vector is incorrect!"
        f" \n Expected {4 ** (len(wires)) - 1}, Given {last_layer_weights.size}"
    )
    dense_layer(last_layer_weights, wires)
    return qml.probs(wires=(0, 2, 4))


fig, ax = qml.draw_mpl(conv_net)(
    np.random.rand(18, 1), np.random.rand(4 ** 3 - 1), np.random.rand(2 ** num_wires)
)
plt.show()

# %%
digits = datasets.load_digits()
images, labels = digits.data, digits.target

images = images[np.where((labels == 0) | (labels == 1)|(labels == 2) | (labels == 3)|(labels == 4) | (labels == 5)|(labels == 6) | (labels == 7))]
labels = labels[np.where((labels == 0) | (labels == 1)|(labels == 2) | (labels == 3)|(labels == 4) | (labels == 5)|(labels == 6) | (labels == 7))]

fig, axes = plt.subplots(nrows=1, ncols=16, figsize=(16, 1))

for i, ax in enumerate(axes.flatten()):
    ax.imshow(images[i].reshape((8, 8)), cmap="gray")
    ax.axis("off")

plt.tight_layout()
plt.subplots_adjust(wspace=0, hspace=0)
plt.show()

# %%
def load_digits_data(num_train, num_test, rng):
    """Return training and testing data of digits dataset."""
    digits = datasets.load_digits()
    features, labels = digits.data, digits.target

    features = features[np.where((labels == 0) | (labels == 1)|(labels == 2) | (labels == 3)|(labels == 4) | (labels == 5)|(labels == 6) | (labels == 7))]
    labels = labels[np.where((labels == 0) | (labels == 1)|(labels == 2) | (labels == 3)|(labels == 4) | (labels == 5)|(labels == 6) | (labels == 7))]

    # normalize data
    features = features / np.linalg.norm(features, axis=1).reshape((-1, 1))

    # subsample train and test split
    train_indices = rng.choice(len(labels), num_train, replace=False)
    test_indices = rng.choice(
        np.setdiff1d(range(len(labels)), train_indices), num_test, replace=False
    )

    x_train, y_train = features[train_indices], labels[train_indices]
    x_test, y_test = features[test_indices], labels[test_indices]

    return (
        jnp.asarray(x_train),
        jnp.asarray(y_train),
        jnp.asarray(x_test),
        jnp.asarray(y_test),
    )

# %%
@jax.jit
def compute_out(weights, weights_last, features, labels):
    """Computes the output of the corresponding label in the qcnn"""
    cost = lambda weights, weights_last, feature, label: conv_net(weights, weights_last, feature)
    return jax.vmap(cost, in_axes=(None, None, 0, 0), out_axes=0)(
        weights, weights_last, features, labels
    )


def compute_accuracy(weights, weights_last, features, labels):
    """Computes the accuracy over the provided features and labels"""
    out = compute_out(weights, weights_last, features, labels)
    pred = jnp.argmax(out, axis = 1)
    return jnp.sum(jnp.array(pred == labels).astype(int)) / len(out)


def compute_cost(weights, weights_last, features, labels):
    """Computes the cost over the provided features and labels"""
    logits = compute_out(weights, weights_last, features, labels)
    return jnp.mean(optax.softmax_cross_entropy_with_integer_labels(logits, labels))


def init_weights():
    """Initializes random weights for the QCNN model."""
    weights = pnp.random.normal(loc=0, scale=1, size=(18, 1), requires_grad=True)
    weights_last = pnp.random.normal(loc=0, scale=1, size=4 ** 3 - 1, requires_grad=True)
    return jnp.array(weights), jnp.array(weights_last)


value_and_grad = jax.jit(jax.value_and_grad(compute_cost, argnums=[0, 1]))

# %%
def batch_data(data, targets, batch_size):
    N = data.shape[0]
    for i in range(0, N, batch_size):
        yield data[i:i + batch_size], targets[i:i + batch_size]

def train_qcnn(n_train, n_test, n_epochs, batch_size = 100):
    """
    Args:
        n_train  (int): number of training examples
        n_test   (int): number of test examples
        n_epochs (int): number of training epochs
        desc  (string): displayed string during optimization

    Returns:
        dict: n_train,
        steps,
        train_cost_epochs,
        train_acc_epochs,
        test_cost_epochs,
        test_acc_epochs

    """
    # load data
    x_train, y_train, x_test, y_test = load_digits_data(n_train, n_test, rng)

    # init weights and optimizer
    weights, weights_last = init_weights()

    optimizer = optax.adam(learning_rate=0.1)
    opt_state = optimizer.init((weights, weights_last))

    # data containers
    train_cost_epochs, test_cost_epochs, train_acc_epochs, test_acc_epochs = [], [], [], []

    for step in range(n_epochs):
        epoch_start = time.time()
        print(f"Training at Epoch {step+1}/{n_epochs}, Train size {n_train}, Test size {n_test}......")
        # Training step with classical optimizer
        # batching
        batch_cost = []
        batch_acc = []
        for batch_id, (x, y) in enumerate(batch_data(x_train, y_train, batch_size)):
          batch_start = time.time()
          train_cost_batch, grad_circuit = value_and_grad(weights, weights_last, x, y)
          updates, opt_state = optimizer.update(grad_circuit, opt_state)
          weights, weights_last = optax.apply_updates((weights, weights_last), updates)

          batch_cost.append(train_cost_batch)

          # compute accuracy on training data
          train_acc_batch = compute_accuracy(weights, weights_last, x, y)
          batch_acc.append(train_acc_batch)
          print(f"Training at Epoch {step+1}/{n_epochs}, Batch {batch_id+1}, Cost {train_cost_batch}, Acc {train_acc_batch}. Time {time.time()-batch_start}")

        train_cost_epochs.append(np.mean(batch_cost))
        train_acc_epochs.append(np.mean(batch_acc))
        #print(f"Epoch {step+1}/{n_epochs}, Train: Cost {np.mean(batch_cost)}, Acc {np.mean(batch_acc)}")

        # compute accuracy and cost on testing data
        test_out = compute_out(weights, weights_last, x_test, y_test)
        test_pred = jnp.argmax(test_out, axis=1)
        test_acc = jnp.sum(jnp.array(test_pred == y_test).astype(int)) / len(test_out)
        test_acc_epochs.append(test_acc)
        test_cost = jnp.mean(optax.softmax_cross_entropy_with_integer_labels(test_out, y_test))
        #test_cost = jnp.mean(optax.softmax_cross_entropy_with_integer_labels(test_out, y_test))
        test_cost_epochs.append(test_cost)
        epoch_end = time.time()
        print(f"Epoch {step+1}/{n_epochs}, Train: Cost {np.mean(batch_cost)}, Acc {np.mean(batch_acc)}; Test: Cost {test_cost}, Acc {test_acc}. Time {time.time()-epoch_start}")
        print("=-="*10)
    return dict(
        n_train=[n_train] * n_epochs,
        step=np.arange(1, n_epochs + 1, dtype=int),
        train_cost=train_cost_epochs,
        train_acc=train_acc_epochs,
        test_cost=test_cost_epochs,
        test_acc=test_acc_epochs,
    )

# %%
n_test = 100
n_epochs = 500
n_reps = 20
batch_size = 2000

train_sizes = [1200]

def run_iterations(n_train):
    results_df = pd.DataFrame(
        columns=["train_acc", "train_cost", "test_acc", "test_cost", "step", "n_train"]
    )

    for _ in range(n_reps):
        results = train_qcnn(n_train=n_train, n_test=n_test, n_epochs=n_epochs, batch_size=batch_size)
        results_df = pd.concat(
            [results_df, pd.DataFrame.from_dict(results)], axis=0, ignore_index=True
        )

    return results_df

results_df = run_iterations(n_train=1200)
#for n_train in train_sizes[1:]:
#    results_df = pd.concat([results_df, run_iterations(n_train=n_train)])
# Out:
# Streaming output truncated to the last 5000 lines.
# Training at Epoch 251/500, Train size 1200, Test size 100......
# Training at Epoch 251/500, Batch 1, Cost 1.951562660509113, Acc 0.8241666666666667. Time 0.07426333427429199
# Epoch 251/500, Train: Cost 1.951562660509113, Acc 0.8241666666666667; Test: Cost 1.9488900415159418, Acc 0.9. Time 0.08074355125427246
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 252/500, Train size 1200, Test size 100......
# Training at Epoch 252/500, Batch 1, Cost 1.951546822031099, Acc 0.8233333333333334. Time 0.07404327392578125
# Epoch 252/500, Train: Cost 1.951546822031099, Acc 0.8233333333333334; Test: Cost 1.9488722486350194, Acc 0.9. Time 0.08003473281860352
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 253/500, Train size 1200, Test size 100......
# Training at Epoch 253/500, Batch 1, Cost 1.95153363020219, Acc 0.8216666666666667. Time 0.0740194320678711
# Epoch 253/500, Train: Cost 1.95153363020219, Acc 0.8216666666666667; Test: Cost 1.9489047525438752, Acc 0.89. Time 0.07999181747436523
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 254/500, Train size 1200, Test size 100......
# Training at Epoch 254/500, Batch 1, Cost 1.9515209343011408, Acc 0.8216666666666667. Time 0.07348895072937012
# Epoch 254/500, Train: Cost 1.9515209343011408, Acc 0.8216666666666667; Test: Cost 1.948835457411592, Acc 0.9. Time 0.08015918731689453
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 255/500, Train size 1200, Test size 100......
# Training at Epoch 255/500, Batch 1, Cost 1.951507458969847, Acc 0.82. Time 0.07424306869506836
# Epoch 255/500, Train: Cost 1.951507458969847, Acc 0.82; Test: Cost 1.9488841569899489, Acc 0.89. Time 0.08057093620300293
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 256/500, Train size 1200, Test size 100......
# Training at Epoch 256/500, Batch 1, Cost 1.9514942460382918, Acc 0.82. Time 0.07422947883605957
# Epoch 256/500, Train: Cost 1.9514942460382918, Acc 0.82; Test: Cost 1.9488613529297556, Acc 0.89. Time 0.08018732070922852
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 257/500, Train size 1200, Test size 100......
# Training at Epoch 257/500, Batch 1, Cost 1.9514825057047522, Acc 0.8191666666666667. Time 0.07393622398376465
# Epoch 257/500, Train: Cost 1.9514825057047522, Acc 0.8191666666666667; Test: Cost 1.9488569574660732, Acc 0.89. Time 0.08076143264770508
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 258/500, Train size 1200, Test size 100......
# Training at Epoch 258/500, Batch 1, Cost 1.9514720380268562, Acc 0.8183333333333334. Time 0.07392525672912598
# Epoch 258/500, Train: Cost 1.9514720380268562, Acc 0.8183333333333334; Test: Cost 1.9488977370273648, Acc 0.89. Time 0.07982254028320312
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 259/500, Train size 1200, Test size 100......
# Training at Epoch 259/500, Batch 1, Cost 1.951461878258185, Acc 0.8183333333333334. Time 0.07400345802307129
# Epoch 259/500, Train: Cost 1.951461878258185, Acc 0.8183333333333334; Test: Cost 1.9488411914732202, Acc 0.88. Time 0.0805666446685791
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 260/500, Train size 1200, Test size 100......
# Training at Epoch 260/500, Batch 1, Cost 1.9514519833808421, Acc 0.8183333333333334. Time 0.07411384582519531
# Epoch 260/500, Train: Cost 1.9514519833808421, Acc 0.8183333333333334; Test: Cost 1.9489099821730542, Acc 0.89. Time 0.08092570304870605
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 261/500, Train size 1200, Test size 100......
# Training at Epoch 261/500, Batch 1, Cost 1.9514430470559214, Acc 0.8183333333333334. Time 0.07378363609313965
# Epoch 261/500, Train: Cost 1.9514430470559214, Acc 0.8183333333333334; Test: Cost 1.9488365619223689, Acc 0.88. Time 0.07977843284606934
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 262/500, Train size 1200, Test size 100......
# Training at Epoch 262/500, Batch 1, Cost 1.951435539321865, Acc 0.8175. Time 0.07356595993041992
# Epoch 262/500, Train: Cost 1.951435539321865, Acc 0.8175; Test: Cost 1.9489223723672222, Acc 0.89. Time 0.079498291015625
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 263/500, Train size 1200, Test size 100......
# Training at Epoch 263/500, Batch 1, Cost 1.9514291191170898, Acc 0.8183333333333334. Time 0.07394123077392578
# Epoch 263/500, Train: Cost 1.9514291191170898, Acc 0.8183333333333334; Test: Cost 1.9488283653774827, Acc 0.88. Time 0.07994890213012695
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 264/500, Train size 1200, Test size 100......
# Training at Epoch 264/500, Batch 1, Cost 1.951423335310295, Acc 0.8183333333333334. Time 0.0738222599029541
# Epoch 264/500, Train: Cost 1.951423335310295, Acc 0.8183333333333334; Test: Cost 1.9489517463043515, Acc 0.89. Time 0.07982873916625977
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 265/500, Train size 1200, Test size 100......
# Training at Epoch 265/500, Batch 1, Cost 1.951418531724116, Acc 0.82. Time 0.07440590858459473
# Epoch 265/500, Train: Cost 1.951418531724116, Acc 0.82; Test: Cost 1.9487933754699074, Acc 0.87. Time 0.08159732818603516
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 266/500, Train size 1200, Test size 100......
# Training at Epoch 266/500, Batch 1, Cost 1.9514161492705713, Acc 0.8191666666666667. Time 0.07379746437072754
# Epoch 266/500, Train: Cost 1.9514161492705713, Acc 0.8191666666666667; Test: Cost 1.9490129229033128, Acc 0.9. Time 0.07985210418701172
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 267/500, Train size 1200, Test size 100......
# Training at Epoch 267/500, Batch 1, Cost 1.9514189880557988, Acc 0.8183333333333334. Time 0.07410025596618652
# Epoch 267/500, Train: Cost 1.9514189880557988, Acc 0.8183333333333334; Test: Cost 1.9487391499352902, Acc 0.87. Time 0.08041763305664062
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 268/500, Train size 1200, Test size 100......
# Training at Epoch 268/500, Batch 1, Cost 1.9514322705284062, Acc 0.8216666666666667. Time 0.07401919364929199
# Epoch 268/500, Train: Cost 1.9514322705284062, Acc 0.8216666666666667; Test: Cost 1.9491684782674608, Acc 0.89. Time 0.08011841773986816
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 269/500, Train size 1200, Test size 100......
# Training at Epoch 269/500, Batch 1, Cost 1.951467780157536, Acc 0.8175. Time 0.07405996322631836
# Epoch 269/500, Train: Cost 1.951467780157536, Acc 0.8175; Test: Cost 1.9487025421999256, Acc 0.87. Time 0.08046340942382812
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 270/500, Train size 1200, Test size 100......
# Training at Epoch 270/500, Batch 1, Cost 1.9515490166418834, Acc 0.8216666666666667. Time 0.07444310188293457
# Epoch 270/500, Train: Cost 1.9515490166418834, Acc 0.8216666666666667; Test: Cost 1.9496316758776895, Acc 0.89. Time 0.08120870590209961
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 271/500, Train size 1200, Test size 100......
# Training at Epoch 271/500, Batch 1, Cost 1.9517271367251101, Acc 0.8125. Time 0.07450485229492188
# Epoch 271/500, Train: Cost 1.9517271367251101, Acc 0.8125; Test: Cost 1.94889081565892, Acc 0.87. Time 0.08062410354614258
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 272/500, Train size 1200, Test size 100......
# Training at Epoch 272/500, Batch 1, Cost 1.9520523960290015, Acc 0.8116666666666666. Time 0.07420516014099121
# Epoch 272/500, Train: Cost 1.9520523960290015, Acc 0.8116666666666666; Test: Cost 1.9507515013094854, Acc 0.89. Time 0.08027505874633789
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 273/500, Train size 1200, Test size 100......
# Training at Epoch 273/500, Batch 1, Cost 1.952541202652298, Acc 0.8108333333333333. Time 0.07419323921203613
# Epoch 273/500, Train: Cost 1.952541202652298, Acc 0.8108333333333333; Test: Cost 1.9493244208386942, Acc 0.87. Time 0.08038997650146484
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 274/500, Train size 1200, Test size 100......
# Training at Epoch 274/500, Batch 1, Cost 1.9527958214721186, Acc 0.8108333333333333. Time 0.07456207275390625
# Epoch 274/500, Train: Cost 1.9527958214721186, Acc 0.8108333333333333; Test: Cost 1.9506859932021423, Acc 0.89. Time 0.08092570304870605
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 275/500, Train size 1200, Test size 100......
# Training at Epoch 275/500, Batch 1, Cost 1.9524722796330973, Acc 0.8183333333333334. Time 0.07398700714111328
# Epoch 275/500, Train: Cost 1.9524722796330973, Acc 0.8183333333333334; Test: Cost 1.9487364067337951, Acc 0.87. Time 0.08017873764038086
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 276/500, Train size 1200, Test size 100......
# Training at Epoch 276/500, Batch 1, Cost 1.9516691762130636, Acc 0.8183333333333334. Time 0.0739738941192627
# Epoch 276/500, Train: Cost 1.9516691762130636, Acc 0.8183333333333334; Test: Cost 1.9488058489549767, Acc 0.87. Time 0.07994341850280762
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 277/500, Train size 1200, Test size 100......
# Training at Epoch 277/500, Batch 1, Cost 1.9513838047462109, Acc 0.8175. Time 0.07389402389526367
# Epoch 277/500, Train: Cost 1.9513838047462109, Acc 0.8175; Test: Cost 1.9497469967523362, Acc 0.88. Time 0.0799715518951416
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 278/500, Train size 1200, Test size 100......
# Training at Epoch 278/500, Batch 1, Cost 1.9517913654343118, Acc 0.8141666666666667. Time 0.07317185401916504
# Epoch 278/500, Train: Cost 1.9517913654343118, Acc 0.8141666666666667; Test: Cost 1.948920678112055, Acc 0.88. Time 0.0799405574798584
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 279/500, Train size 1200, Test size 100......
# Training at Epoch 279/500, Batch 1, Cost 1.952130469514477, Acc 0.8125. Time 0.07385110855102539
# Epoch 279/500, Train: Cost 1.952130469514477, Acc 0.8125; Test: Cost 1.9498963025190117, Acc 0.88. Time 0.07997536659240723
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 280/500, Train size 1200, Test size 100......
# Training at Epoch 280/500, Batch 1, Cost 1.9518747865781814, Acc 0.8216666666666667. Time 0.0742030143737793
# Epoch 280/500, Train: Cost 1.9518747865781814, Acc 0.8216666666666667; Test: Cost 1.948707864936385, Acc 0.87. Time 0.0807654857635498
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 281/500, Train size 1200, Test size 100......
# Training at Epoch 281/500, Batch 1, Cost 1.951404540103943, Acc 0.8158333333333333. Time 0.0736997127532959
# Epoch 281/500, Train: Cost 1.951404540103943, Acc 0.8158333333333333; Test: Cost 1.9486978996249895, Acc 0.87. Time 0.07977795600891113
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 282/500, Train size 1200, Test size 100......
# Training at Epoch 282/500, Batch 1, Cost 1.9514570192748617, Acc 0.815. Time 0.0733027458190918
# Epoch 282/500, Train: Cost 1.9514570192748617, Acc 0.815; Test: Cost 1.9496974325026815, Acc 0.88. Time 0.07902908325195312
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 283/500, Train size 1200, Test size 100......
# Training at Epoch 283/500, Batch 1, Cost 1.9517978716805677, Acc 0.8175. Time 0.07376599311828613
# Epoch 283/500, Train: Cost 1.9517978716805677, Acc 0.8175; Test: Cost 1.948701296836485, Acc 0.88. Time 0.07985448837280273
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 284/500, Train size 1200, Test size 100......
# Training at Epoch 284/500, Batch 1, Cost 1.9517345729444273, Acc 0.8191666666666667. Time 0.07435226440429688
# Epoch 284/500, Train: Cost 1.9517345729444273, Acc 0.8191666666666667; Test: Cost 1.9490442129017658, Acc 0.88. Time 0.08032822608947754
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 285/500, Train size 1200, Test size 100......
# Training at Epoch 285/500, Batch 1, Cost 1.9514021409866906, Acc 0.82. Time 0.07415056228637695
# Epoch 285/500, Train: Cost 1.9514021409866906, Acc 0.82; Test: Cost 1.948977350682152, Acc 0.87. Time 0.08097052574157715
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 286/500, Train size 1200, Test size 100......
# Training at Epoch 286/500, Batch 1, Cost 1.9513706116080525, Acc 0.8175. Time 0.0731210708618164
# Epoch 286/500, Train: Cost 1.9513706116080525, Acc 0.8175; Test: Cost 1.948680913736975, Acc 0.87. Time 0.07881975173950195
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 287/500, Train size 1200, Test size 100......
# Training at Epoch 287/500, Batch 1, Cost 1.9515972346801536, Acc 0.8183333333333334. Time 0.07295393943786621
# Epoch 287/500, Train: Cost 1.9515972346801536, Acc 0.8183333333333334; Test: Cost 1.9493964475450498, Acc 0.88. Time 0.07895374298095703
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 288/500, Train size 1200, Test size 100......
# Training at Epoch 288/500, Batch 1, Cost 1.951602104962201, Acc 0.8158333333333333. Time 0.07412362098693848
# Epoch 288/500, Train: Cost 1.951602104962201, Acc 0.8158333333333333; Test: Cost 1.9486469721292887, Acc 0.87. Time 0.0803537368774414
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 289/500, Train size 1200, Test size 100......
# Training at Epoch 289/500, Batch 1, Cost 1.9513796986262053, Acc 0.8208333333333333. Time 0.0738835334777832
# Epoch 289/500, Train: Cost 1.9513796986262053, Acc 0.8208333333333333; Test: Cost 1.9486420218852953, Acc 0.87. Time 0.0799410343170166
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 290/500, Train size 1200, Test size 100......
# Training at Epoch 290/500, Batch 1, Cost 1.9513412286363676, Acc 0.8191666666666667. Time 0.07378625869750977
# Epoch 290/500, Train: Cost 1.9513412286363676, Acc 0.8191666666666667; Test: Cost 1.9491889387221826, Acc 0.89. Time 0.08058047294616699
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 291/500, Train size 1200, Test size 100......
# Training at Epoch 291/500, Batch 1, Cost 1.951485266839189, Acc 0.8166666666666667. Time 0.07335329055786133
# Epoch 291/500, Train: Cost 1.951485266839189, Acc 0.8166666666666667; Test: Cost 1.948589024333779, Acc 0.87. Time 0.07996010780334473
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 292/500, Train size 1200, Test size 100......
# Training at Epoch 292/500, Batch 1, Cost 1.9514930382488938, Acc 0.8191666666666667. Time 0.07381367683410645
# Epoch 292/500, Train: Cost 1.9514930382488938, Acc 0.8191666666666667; Test: Cost 1.9489130370515761, Acc 0.89. Time 0.07999920845031738
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 293/500, Train size 1200, Test size 100......
# Training at Epoch 293/500, Batch 1, Cost 1.9513580160371682, Acc 0.82. Time 0.07444024085998535
# Epoch 293/500, Train: Cost 1.9513580160371682, Acc 0.82; Test: Cost 1.9488203500273376, Acc 0.87. Time 0.08044075965881348
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 294/500, Train size 1200, Test size 100......
# Training at Epoch 294/500, Batch 1, Cost 1.9513175463655394, Acc 0.8158333333333333. Time 0.07390213012695312
# Epoch 294/500, Train: Cost 1.9513175463655394, Acc 0.8158333333333333; Test: Cost 1.948595902843307, Acc 0.87. Time 0.079986572265625
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 295/500, Train size 1200, Test size 100......
# Training at Epoch 295/500, Batch 1, Cost 1.9514036086373547, Acc 0.8233333333333334. Time 0.07337737083435059
# Epoch 295/500, Train: Cost 1.9514036086373547, Acc 0.8233333333333334; Test: Cost 1.9491028211345955, Acc 0.89. Time 0.0791015625
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 296/500, Train size 1200, Test size 100......
# Training at Epoch 296/500, Batch 1, Cost 1.9514259175817197, Acc 0.815. Time 0.07347822189331055
# Epoch 296/500, Train: Cost 1.9514259175817197, Acc 0.815; Test: Cost 1.9486052609215967, Acc 0.87. Time 0.07953858375549316
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 297/500, Train size 1200, Test size 100......
# Training at Epoch 297/500, Batch 1, Cost 1.9513367731780364, Acc 0.8208333333333333. Time 0.07410693168640137
# Epoch 297/500, Train: Cost 1.9513367731780364, Acc 0.8208333333333333; Test: Cost 1.94867228509143, Acc 0.87. Time 0.08106565475463867
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 298/500, Train size 1200, Test size 100......
# Training at Epoch 298/500, Batch 1, Cost 1.9512971438219082, Acc 0.82. Time 0.07434868812561035
# Epoch 298/500, Train: Cost 1.9512971438219082, Acc 0.82; Test: Cost 1.948917650586924, Acc 0.89. Time 0.08025360107421875
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 299/500, Train size 1200, Test size 100......
# Training at Epoch 299/500, Batch 1, Cost 1.9513531737815684, Acc 0.8141666666666667. Time 0.07380867004394531
# Epoch 299/500, Train: Cost 1.9513531737815684, Acc 0.8141666666666667; Test: Cost 1.9485548690538381, Acc 0.87. Time 0.07958245277404785
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 300/500, Train size 1200, Test size 100......
# Training at Epoch 300/500, Batch 1, Cost 1.9513756346234694, Acc 0.8233333333333334. Time 0.07356595993041992
# Epoch 300/500, Train: Cost 1.9513756346234694, Acc 0.8233333333333334; Test: Cost 1.9488142931870676, Acc 0.9. Time 0.07929873466491699
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 301/500, Train size 1200, Test size 100......
# Training at Epoch 301/500, Batch 1, Cost 1.951317304656388, Acc 0.8216666666666667. Time 0.07329058647155762
# Epoch 301/500, Train: Cost 1.951317304656388, Acc 0.8216666666666667; Test: Cost 1.9486847045433893, Acc 0.87. Time 0.0790250301361084
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 302/500, Train size 1200, Test size 100......
# Training at Epoch 302/500, Batch 1, Cost 1.9512815966396035, Acc 0.815. Time 0.07396483421325684
# Epoch 302/500, Train: Cost 1.9512815966396035, Acc 0.815; Test: Cost 1.9485582557405337, Acc 0.87. Time 0.07999634742736816
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 303/500, Train size 1200, Test size 100......
# Training at Epoch 303/500, Batch 1, Cost 1.9513160016571833, Acc 0.8208333333333333. Time 0.07385444641113281
# Epoch 303/500, Train: Cost 1.9513160016571833, Acc 0.8208333333333333; Test: Cost 1.948887308780763, Acc 0.89. Time 0.08014106750488281
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 304/500, Train size 1200, Test size 100......
# Training at Epoch 304/500, Batch 1, Cost 1.9513375555349206, Acc 0.8175. Time 0.07423901557922363
# Epoch 304/500, Train: Cost 1.9513375555349206, Acc 0.8175; Test: Cost 1.948540932107617, Acc 0.87. Time 0.08055925369262695
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 305/500, Train size 1200, Test size 100......
# Training at Epoch 305/500, Batch 1, Cost 1.9513008388128652, Acc 0.8191666666666667. Time 0.0740957260131836
# Epoch 305/500, Train: Cost 1.9513008388128652, Acc 0.8191666666666667; Test: Cost 1.9486311582588378, Acc 0.87. Time 0.08007955551147461
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 306/500, Train size 1200, Test size 100......
# Training at Epoch 306/500, Batch 1, Cost 1.9512709421889085, Acc 0.8216666666666667. Time 0.07422924041748047
# Epoch 306/500, Train: Cost 1.9512709421889085, Acc 0.8216666666666667; Test: Cost 1.9487257515391883, Acc 0.88. Time 0.08054089546203613
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 307/500, Train size 1200, Test size 100......
# Training at Epoch 307/500, Batch 1, Cost 1.951287541183511, Acc 0.8166666666666667. Time 0.07402968406677246
# Epoch 307/500, Train: Cost 1.951287541183511, Acc 0.8166666666666667; Test: Cost 1.9485028852392345, Acc 0.87. Time 0.08072948455810547
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 308/500, Train size 1200, Test size 100......
# Training at Epoch 308/500, Batch 1, Cost 1.9513049704567509, Acc 0.8225. Time 0.07424330711364746
# Epoch 308/500, Train: Cost 1.9513049704567509, Acc 0.8225; Test: Cost 1.9487379562767375, Acc 0.88. Time 0.08037495613098145
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 309/500, Train size 1200, Test size 100......
# Training at Epoch 309/500, Batch 1, Cost 1.9512872471844238, Acc 0.82. Time 0.07392740249633789
# Epoch 309/500, Train: Cost 1.9512872471844238, Acc 0.82; Test: Cost 1.9485626969135654, Acc 0.87. Time 0.08003473281860352
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 310/500, Train size 1200, Test size 100......
# Training at Epoch 310/500, Batch 1, Cost 1.9512629346611037, Acc 0.8175. Time 0.0738527774810791
# Epoch 310/500, Train: Cost 1.9512629346611037, Acc 0.8175; Test: Cost 1.9485425853408105, Acc 0.87. Time 0.07999944686889648
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 311/500, Train size 1200, Test size 100......
# Training at Epoch 311/500, Batch 1, Cost 1.951265077337436, Acc 0.8208333333333333. Time 0.07442045211791992
# Epoch 311/500, Train: Cost 1.951265077337436, Acc 0.8208333333333333; Test: Cost 1.9487174311619544, Acc 0.88. Time 0.08115887641906738
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 312/500, Train size 1200, Test size 100......
# Training at Epoch 312/500, Batch 1, Cost 1.9512780982996147, Acc 0.82. Time 0.07445740699768066
# Epoch 312/500, Train: Cost 1.9512780982996147, Acc 0.82; Test: Cost 1.9485085086637401, Acc 0.87. Time 0.0806739330291748
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 313/500, Train size 1200, Test size 100......
# Training at Epoch 313/500, Batch 1, Cost 1.951273460381157, Acc 0.82. Time 0.0742807388305664
# Epoch 313/500, Train: Cost 1.951273460381157, Acc 0.82; Test: Cost 1.9486314043730784, Acc 0.87. Time 0.08022069931030273
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 314/500, Train size 1200, Test size 100......
# Training at Epoch 314/500, Batch 1, Cost 1.9512557918710045, Acc 0.8216666666666667. Time 0.07353830337524414
# Epoch 314/500, Train: Cost 1.9512557918710045, Acc 0.8216666666666667; Test: Cost 1.9485942142320085, Acc 0.87. Time 0.07965779304504395
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 315/500, Train size 1200, Test size 100......
# Training at Epoch 315/500, Batch 1, Cost 1.9512484493994013, Acc 0.8191666666666667. Time 0.07418608665466309
# Epoch 315/500, Train: Cost 1.9512484493994013, Acc 0.8191666666666667; Test: Cost 1.9484987578588548, Acc 0.87. Time 0.08035683631896973
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 316/500, Train size 1200, Test size 100......
# Training at Epoch 316/500, Batch 1, Cost 1.9512551802800693, Acc 0.8191666666666667. Time 0.0747067928314209
# Epoch 316/500, Train: Cost 1.9512551802800693, Acc 0.8191666666666667; Test: Cost 1.9486770183168158, Acc 0.87. Time 0.08100461959838867
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 317/500, Train size 1200, Test size 100......
# Training at Epoch 317/500, Batch 1, Cost 1.9512580281885934, Acc 0.8208333333333333. Time 0.07382345199584961
# Epoch 317/500, Train: Cost 1.9512580281885934, Acc 0.8208333333333333; Test: Cost 1.9484946759872082, Acc 0.87. Time 0.08052635192871094
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 318/500, Train size 1200, Test size 100......
# Training at Epoch 318/500, Batch 1, Cost 1.9512478202996386, Acc 0.82. Time 0.07397580146789551
# Epoch 318/500, Train: Cost 1.9512478202996386, Acc 0.82; Test: Cost 1.9485764067783142, Acc 0.87. Time 0.08075952529907227
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 319/500, Train size 1200, Test size 100......
# Training at Epoch 319/500, Batch 1, Cost 1.951236954449671, Acc 0.8225. Time 0.07375478744506836
# Epoch 319/500, Train: Cost 1.951236954449671, Acc 0.8225; Test: Cost 1.9485823455590576, Acc 0.87. Time 0.07980632781982422
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 320/500, Train size 1200, Test size 100......
# Training at Epoch 320/500, Batch 1, Cost 1.9512368213811413, Acc 0.8191666666666667. Time 0.07411456108093262
# Epoch 320/500, Train: Cost 1.9512368213811413, Acc 0.8191666666666667; Test: Cost 1.9485034072913445, Acc 0.87. Time 0.0805215835571289
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 321/500, Train size 1200, Test size 100......
# Training at Epoch 321/500, Batch 1, Cost 1.9512409921703042, Acc 0.8216666666666667. Time 0.07403326034545898
# Epoch 321/500, Train: Cost 1.9512409921703042, Acc 0.8216666666666667; Test: Cost 1.9485997076230184, Acc 0.87. Time 0.07984614372253418
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 322/500, Train size 1200, Test size 100......
# Training at Epoch 322/500, Batch 1, Cost 1.9512377523797917, Acc 0.82. Time 0.07378029823303223
# Epoch 322/500, Train: Cost 1.9512377523797917, Acc 0.82; Test: Cost 1.948523631453831, Acc 0.87. Time 0.07996225357055664
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 323/500, Train size 1200, Test size 100......
# Training at Epoch 323/500, Batch 1, Cost 1.951228499478856, Acc 0.8216666666666667. Time 0.0733940601348877
# Epoch 323/500, Train: Cost 1.951228499478856, Acc 0.8216666666666667; Test: Cost 1.9484895710133179, Acc 0.87. Time 0.07909369468688965
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 324/500, Train size 1200, Test size 100......
# Training at Epoch 324/500, Batch 1, Cost 1.951223450630173, Acc 0.82. Time 0.0729818344116211
# Epoch 324/500, Train: Cost 1.951223450630173, Acc 0.82; Test: Cost 1.948612627589473, Acc 0.87. Time 0.07902264595031738
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 325/500, Train size 1200, Test size 100......
# Training at Epoch 325/500, Batch 1, Cost 1.9512249886846913, Acc 0.8208333333333333. Time 0.07424235343933105
# Epoch 325/500, Train: Cost 1.9512249886846913, Acc 0.8208333333333333; Test: Cost 1.9484153180707113, Acc 0.87. Time 0.08107423782348633
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 326/500, Train size 1200, Test size 100......
# Training at Epoch 326/500, Batch 1, Cost 1.9512261500882013, Acc 0.8191666666666667. Time 0.07396674156188965
# Epoch 326/500, Train: Cost 1.9512261500882013, Acc 0.8191666666666667; Test: Cost 1.9486435815188277, Acc 0.87. Time 0.08016705513000488
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 327/500, Train size 1200, Test size 100......
# Training at Epoch 327/500, Batch 1, Cost 1.9512229162590922, Acc 0.8208333333333333. Time 0.07346415519714355
# Epoch 327/500, Train: Cost 1.9512229162590922, Acc 0.8208333333333333; Test: Cost 1.9483925422831159, Acc 0.87. Time 0.07934403419494629
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 328/500, Train size 1200, Test size 100......
# Training at Epoch 328/500, Batch 1, Cost 1.951219812016786, Acc 0.8175. Time 0.07445740699768066
# Epoch 328/500, Train: Cost 1.951219812016786, Acc 0.8175; Test: Cost 1.9486427772480535, Acc 0.87. Time 0.0833442211151123
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 329/500, Train size 1200, Test size 100......
# Training at Epoch 329/500, Batch 1, Cost 1.9512232912496321, Acc 0.8216666666666667. Time 0.07574343681335449
# Epoch 329/500, Train: Cost 1.9512232912496321, Acc 0.8216666666666667; Test: Cost 1.9483716177180623, Acc 0.87. Time 0.08180737495422363
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 330/500, Train size 1200, Test size 100......
# Training at Epoch 330/500, Batch 1, Cost 1.9512360857803925, Acc 0.8175. Time 0.0744028091430664
# Epoch 330/500, Train: Cost 1.9512360857803925, Acc 0.8175; Test: Cost 1.948769838986747, Acc 0.88. Time 0.08062005043029785
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 331/500, Train size 1200, Test size 100......
# Training at Epoch 331/500, Batch 1, Cost 1.9512603058877647, Acc 0.8241666666666667. Time 0.07388472557067871
# Epoch 331/500, Train: Cost 1.9512603058877647, Acc 0.8241666666666667; Test: Cost 1.948254708228202, Acc 0.87. Time 0.0797889232635498
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 332/500, Train size 1200, Test size 100......
# Training at Epoch 332/500, Batch 1, Cost 1.9513080149168383, Acc 0.8108333333333333. Time 0.07341909408569336
# Epoch 332/500, Train: Cost 1.9513080149168383, Acc 0.8108333333333333; Test: Cost 1.9491887906291003, Acc 0.86. Time 0.07956290245056152
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 333/500, Train size 1200, Test size 100......
# Training at Epoch 333/500, Batch 1, Cost 1.9514019894380206, Acc 0.825. Time 0.07344985008239746
# Epoch 333/500, Train: Cost 1.9514019894380206, Acc 0.825; Test: Cost 1.948139350701951, Acc 0.87. Time 0.07934904098510742
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 334/500, Train size 1200, Test size 100......
# Training at Epoch 334/500, Batch 1, Cost 1.9515865439297722, Acc 0.8033333333333333. Time 0.07388186454772949
# Epoch 334/500, Train: Cost 1.9515865439297722, Acc 0.8033333333333333; Test: Cost 1.9501339031009304, Acc 0.86. Time 0.08177661895751953
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 335/500, Train size 1200, Test size 100......
# Training at Epoch 335/500, Batch 1, Cost 1.9518761635273378, Acc 0.8233333333333334. Time 0.0742037296295166
# Epoch 335/500, Train: Cost 1.9518761635273378, Acc 0.8233333333333334; Test: Cost 1.9483265515148913, Acc 0.87. Time 0.081207275390625
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 336/500, Train size 1200, Test size 100......
# Training at Epoch 336/500, Batch 1, Cost 1.9522604912025054, Acc 0.7925. Time 0.07443571090698242
# Epoch 336/500, Train: Cost 1.9522604912025054, Acc 0.7925; Test: Cost 1.9510017642188964, Acc 0.85. Time 0.08063483238220215
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 337/500, Train size 1200, Test size 100......
# Training at Epoch 337/500, Batch 1, Cost 1.952419250500579, Acc 0.8233333333333334. Time 0.07384777069091797
# Epoch 337/500, Train: Cost 1.952419250500579, Acc 0.8233333333333334; Test: Cost 1.9483364143391873, Acc 0.87. Time 0.07973957061767578
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 338/500, Train size 1200, Test size 100......
# Training at Epoch 338/500, Batch 1, Cost 1.9521659818399653, Acc 0.8075. Time 0.07358503341674805
# Epoch 338/500, Train: Cost 1.9521659818399653, Acc 0.8075; Test: Cost 1.9494983472659693, Acc 0.86. Time 0.07965850830078125
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 339/500, Train size 1200, Test size 100......
# Training at Epoch 339/500, Batch 1, Cost 1.9515398187848807, Acc 0.8233333333333334. Time 0.07432341575622559
# Epoch 339/500, Train: Cost 1.9515398187848807, Acc 0.8233333333333334; Test: Cost 1.948459323431584, Acc 0.87. Time 0.08121299743652344
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 340/500, Train size 1200, Test size 100......
# Training at Epoch 340/500, Batch 1, Cost 1.9511871994363645, Acc 0.8258333333333333. Time 0.07390260696411133
# Epoch 340/500, Train: Cost 1.9511871994363645, Acc 0.8258333333333333; Test: Cost 1.9481275542944623, Acc 0.87. Time 0.08072495460510254
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 341/500, Train size 1200, Test size 100......
# Training at Epoch 341/500, Batch 1, Cost 1.9513640073590706, Acc 0.805. Time 0.0740044116973877
# Epoch 341/500, Train: Cost 1.9513640073590706, Acc 0.805; Test: Cost 1.9498152485734646, Acc 0.86. Time 0.08009767532348633
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 342/500, Train size 1200, Test size 100......
# Training at Epoch 342/500, Batch 1, Cost 1.951719600731724, Acc 0.825. Time 0.07414984703063965
# Epoch 342/500, Train: Cost 1.951719600731724, Acc 0.825; Test: Cost 1.948169254343371, Acc 0.87. Time 0.08034586906433105
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 343/500, Train size 1200, Test size 100......
# Training at Epoch 343/500, Batch 1, Cost 1.9517729616850845, Acc 0.81. Time 0.07390046119689941
# Epoch 343/500, Train: Cost 1.9517729616850845, Acc 0.81; Test: Cost 1.9492456482355869, Acc 0.86. Time 0.07988739013671875
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 344/500, Train size 1200, Test size 100......
# Training at Epoch 344/500, Batch 1, Cost 1.9514374294812433, Acc 0.8233333333333334. Time 0.07522058486938477
# Epoch 344/500, Train: Cost 1.9514374294812433, Acc 0.8233333333333334; Test: Cost 1.9483516420986515, Acc 0.87. Time 0.08142399787902832
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 345/500, Train size 1200, Test size 100......
# Training at Epoch 345/500, Batch 1, Cost 1.9511723407411767, Acc 0.8258333333333333. Time 0.07405757904052734
# Epoch 345/500, Train: Cost 1.9511723407411767, Acc 0.8258333333333333; Test: Cost 1.948134761882592, Acc 0.87. Time 0.08100199699401855
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 346/500, Train size 1200, Test size 100......
# Training at Epoch 346/500, Batch 1, Cost 1.9512687337650712, Acc 0.8083333333333333. Time 0.07423019409179688
# Epoch 346/500, Train: Cost 1.9512687337650712, Acc 0.8083333333333333; Test: Cost 1.9494073464671209, Acc 0.86. Time 0.08072948455810547
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 347/500, Train size 1200, Test size 100......
# Training at Epoch 347/500, Batch 1, Cost 1.9514943108558798, Acc 0.8275. Time 0.07402658462524414
# Epoch 347/500, Train: Cost 1.9514943108558798, Acc 0.8275; Test: Cost 1.9480976471614577, Acc 0.87. Time 0.0805811882019043
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 348/500, Train size 1200, Test size 100......
# Training at Epoch 348/500, Batch 1, Cost 1.951489596763475, Acc 0.8125. Time 0.07412052154541016
# Epoch 348/500, Train: Cost 1.951489596763475, Acc 0.8125; Test: Cost 1.9488447613160378, Acc 0.88. Time 0.08068633079528809
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 349/500, Train size 1200, Test size 100......
# Training at Epoch 349/500, Batch 1, Cost 1.951263401758876, Acc 0.825. Time 0.07436013221740723
# Epoch 349/500, Train: Cost 1.951263401758876, Acc 0.825; Test: Cost 1.9484097335579853, Acc 0.87. Time 0.08156585693359375
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 350/500, Train size 1200, Test size 100......
# Training at Epoch 350/500, Batch 1, Cost 1.9511402103966335, Acc 0.8258333333333333. Time 0.07456374168395996
# Epoch 350/500, Train: Cost 1.9511402103966335, Acc 0.8258333333333333; Test: Cost 1.948059738976077, Acc 0.87. Time 0.08094930648803711
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 351/500, Train size 1200, Test size 100......
# Training at Epoch 351/500, Batch 1, Cost 1.9512447924305572, Acc 0.8125. Time 0.07378363609313965
# Epoch 351/500, Train: Cost 1.9512447924305572, Acc 0.8125; Test: Cost 1.949118352746009, Acc 0.86. Time 0.07988262176513672
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 352/500, Train size 1200, Test size 100......
# Training at Epoch 352/500, Batch 1, Cost 1.9513626398753252, Acc 0.8266666666666667. Time 0.07338094711303711
# Epoch 352/500, Train: Cost 1.9513626398753252, Acc 0.8266666666666667; Test: Cost 1.9480895152069715, Acc 0.87. Time 0.07966446876525879
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 353/500, Train size 1200, Test size 100......
# Training at Epoch 353/500, Batch 1, Cost 1.9513007766953272, Acc 0.8175. Time 0.07398080825805664
# Epoch 353/500, Train: Cost 1.9513007766953272, Acc 0.8175; Test: Cost 1.9485312800499606, Acc 0.88. Time 0.08079910278320312
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 354/500, Train size 1200, Test size 100......
# Training at Epoch 354/500, Batch 1, Cost 1.9511558014858794, Acc 0.8208333333333333. Time 0.07448840141296387
# Epoch 354/500, Train: Cost 1.9511558014858794, Acc 0.8208333333333333; Test: Cost 1.9484634975145851, Acc 0.87. Time 0.08082270622253418
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 355/500, Train size 1200, Test size 100......
# Training at Epoch 355/500, Batch 1, Cost 1.95112468906508, Acc 0.825. Time 0.07385706901550293
# Epoch 355/500, Train: Cost 1.95112468906508, Acc 0.825; Test: Cost 1.9480195494913937, Acc 0.87. Time 0.08013701438903809
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 356/500, Train size 1200, Test size 100......
# Training at Epoch 356/500, Batch 1, Cost 1.951207554029915, Acc 0.8133333333333334. Time 0.07391047477722168
# Epoch 356/500, Train: Cost 1.951207554029915, Acc 0.8133333333333334; Test: Cost 1.9488354360347462, Acc 0.86. Time 0.08124661445617676
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 357/500, Train size 1200, Test size 100......
# Training at Epoch 357/500, Batch 1, Cost 1.9512482686591168, Acc 0.825. Time 0.07317399978637695
# Epoch 357/500, Train: Cost 1.9512482686591168, Acc 0.825; Test: Cost 1.9480863518355205, Acc 0.87. Time 0.07950496673583984
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 358/500, Train size 1200, Test size 100......
# Training at Epoch 358/500, Batch 1, Cost 1.9511804592700106, Acc 0.8216666666666667. Time 0.07421588897705078
# Epoch 358/500, Train: Cost 1.9511804592700106, Acc 0.8216666666666667; Test: Cost 1.9483315617016104, Acc 0.88. Time 0.08065247535705566
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 359/500, Train size 1200, Test size 100......
# Training at Epoch 359/500, Batch 1, Cost 1.9511010150655346, Acc 0.82. Time 0.07386660575866699
# Epoch 359/500, Train: Cost 1.9511010150655346, Acc 0.82; Test: Cost 1.9484500518618233, Acc 0.87. Time 0.08119058609008789
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 360/500, Train size 1200, Test size 100......
# Training at Epoch 360/500, Batch 1, Cost 1.9511026430224578, Acc 0.8225. Time 0.07421016693115234
# Epoch 360/500, Train: Cost 1.9511026430224578, Acc 0.8225; Test: Cost 1.9480039830352491, Acc 0.87. Time 0.08068990707397461
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 361/500, Train size 1200, Test size 100......
# Training at Epoch 361/500, Batch 1, Cost 1.9511497699832547, Acc 0.8133333333333334. Time 0.07391071319580078
# Epoch 361/500, Train: Cost 1.9511497699832547, Acc 0.8133333333333334; Test: Cost 1.9486274594165927, Acc 0.88. Time 0.08020853996276855
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 362/500, Train size 1200, Test size 100......
# Training at Epoch 362/500, Batch 1, Cost 1.9511548810835198, Acc 0.8241666666666667. Time 0.07392120361328125
# Epoch 362/500, Train: Cost 1.9511548810835198, Acc 0.8241666666666667; Test: Cost 1.9480726092992526, Acc 0.87. Time 0.08057737350463867
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 363/500, Train size 1200, Test size 100......
# Training at Epoch 363/500, Batch 1, Cost 1.9511048385136263, Acc 0.8225. Time 0.07430124282836914
# Epoch 363/500, Train: Cost 1.9511048385136263, Acc 0.8225; Test: Cost 1.948199668396263, Acc 0.88. Time 0.08050704002380371
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 364/500, Train size 1200, Test size 100......
# Training at Epoch 364/500, Batch 1, Cost 1.9510609072055871, Acc 0.8208333333333333. Time 0.0741124153137207
# Epoch 364/500, Train: Cost 1.9510609072055871, Acc 0.8208333333333333; Test: Cost 1.9483762959392186, Acc 0.88. Time 0.08038854598999023
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 365/500, Train size 1200, Test size 100......
# Training at Epoch 365/500, Batch 1, Cost 1.9510630209345345, Acc 0.8233333333333334. Time 0.0734093189239502
# Epoch 365/500, Train: Cost 1.9510630209345345, Acc 0.8233333333333334; Test: Cost 1.9479457430264553, Acc 0.87. Time 0.0794374942779541
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 366/500, Train size 1200, Test size 100......
# Training at Epoch 366/500, Batch 1, Cost 1.9510836278851613, Acc 0.8191666666666667. Time 0.07351946830749512
# Epoch 366/500, Train: Cost 1.9510836278851613, Acc 0.8191666666666667; Test: Cost 1.948418097720418, Acc 0.88. Time 0.07979416847229004
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 367/500, Train size 1200, Test size 100......
# Training at Epoch 367/500, Batch 1, Cost 1.9510782993461855, Acc 0.8233333333333334. Time 0.07433629035949707
# Epoch 367/500, Train: Cost 1.9510782993461855, Acc 0.8233333333333334; Test: Cost 1.9480223888274903, Acc 0.87. Time 0.08093976974487305
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 368/500, Train size 1200, Test size 100......
# Training at Epoch 368/500, Batch 1, Cost 1.951045232832651, Acc 0.8208333333333333. Time 0.07321977615356445
# Epoch 368/500, Train: Cost 1.951045232832651, Acc 0.8208333333333333; Test: Cost 1.948089846918159, Acc 0.88. Time 0.07929348945617676
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 369/500, Train size 1200, Test size 100......
# Training at Epoch 369/500, Batch 1, Cost 1.951016360517541, Acc 0.8233333333333334. Time 0.07303047180175781
# Epoch 369/500, Train: Cost 1.951016360517541, Acc 0.8233333333333334; Test: Cost 1.9482420153084912, Acc 0.88. Time 0.07882308959960938
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 370/500, Train size 1200, Test size 100......
# Training at Epoch 370/500, Batch 1, Cost 1.9510100960309835, Acc 0.8241666666666667. Time 0.07296037673950195
# Epoch 370/500, Train: Cost 1.9510100960309835, Acc 0.8241666666666667; Test: Cost 1.947900096835782, Acc 0.87. Time 0.07885980606079102
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 371/500, Train size 1200, Test size 100......
# Training at Epoch 371/500, Batch 1, Cost 1.9510126449784648, Acc 0.82. Time 0.07360148429870605
# Epoch 371/500, Train: Cost 1.9510126449784648, Acc 0.82; Test: Cost 1.948247435242709, Acc 0.88. Time 0.07982063293457031
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 372/500, Train size 1200, Test size 100......
# Training at Epoch 372/500, Batch 1, Cost 1.9510035704029574, Acc 0.8233333333333334. Time 0.07376623153686523
# Epoch 372/500, Train: Cost 1.9510035704029574, Acc 0.8233333333333334; Test: Cost 1.947930973248197, Acc 0.87. Time 0.07984733581542969
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 373/500, Train size 1200, Test size 100......
# Training at Epoch 373/500, Batch 1, Cost 1.95098140865625, Acc 0.8216666666666667. Time 0.07365870475769043
# Epoch 373/500, Train: Cost 1.95098140865625, Acc 0.8216666666666667; Test: Cost 1.9480108150852353, Acc 0.88. Time 0.07952475547790527
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 374/500, Train size 1200, Test size 100......
# Training at Epoch 374/500, Batch 1, Cost 1.9509594456973216, Acc 0.8233333333333334. Time 0.07368779182434082
# Epoch 374/500, Train: Cost 1.9509594456973216, Acc 0.8233333333333334; Test: Cost 1.9480824098831488, Acc 0.89. Time 0.08047604560852051
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 375/500, Train size 1200, Test size 100......
# Training at Epoch 375/500, Batch 1, Cost 1.9509455947995094, Acc 0.825. Time 0.07352590560913086
# Epoch 375/500, Train: Cost 1.9509455947995094, Acc 0.825; Test: Cost 1.9478201947969374, Acc 0.87. Time 0.079559326171875
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 376/500, Train size 1200, Test size 100......
# Training at Epoch 376/500, Batch 1, Cost 1.9509350297381913, Acc 0.82. Time 0.07407593727111816
# Epoch 376/500, Train: Cost 1.9509350297381913, Acc 0.82; Test: Cost 1.948085657147322, Acc 0.88. Time 0.08019804954528809
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 377/500, Train size 1200, Test size 100......
# Training at Epoch 377/500, Batch 1, Cost 1.9509205434094987, Acc 0.8241666666666667. Time 0.07319164276123047
# Epoch 377/500, Train: Cost 1.9509205434094987, Acc 0.8241666666666667; Test: Cost 1.9478109186763422, Acc 0.87. Time 0.07888054847717285
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 378/500, Train size 1200, Test size 100......
# Training at Epoch 378/500, Batch 1, Cost 1.9509013949611453, Acc 0.8208333333333333. Time 0.07274103164672852
# Epoch 378/500, Train: Cost 1.9509013949611453, Acc 0.8208333333333333; Test: Cost 1.947907631556474, Acc 0.88. Time 0.07862114906311035
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 379/500, Train size 1200, Test size 100......
# Training at Epoch 379/500, Batch 1, Cost 1.9508821356692834, Acc 0.8241666666666667. Time 0.07268762588500977
# Epoch 379/500, Train: Cost 1.9508821356692834, Acc 0.8241666666666667; Test: Cost 1.947904976125674, Acc 0.89. Time 0.07822179794311523
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 380/500, Train size 1200, Test size 100......
# Training at Epoch 380/500, Batch 1, Cost 1.9508648599383067, Acc 0.8216666666666667. Time 0.07254815101623535
# Epoch 380/500, Train: Cost 1.9508648599383067, Acc 0.8216666666666667; Test: Cost 1.9477248043126638, Acc 0.88. Time 0.07883834838867188
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 381/500, Train size 1200, Test size 100......
# Training at Epoch 381/500, Batch 1, Cost 1.9508468975412523, Acc 0.8208333333333333. Time 0.07410573959350586
# Epoch 381/500, Train: Cost 1.9508468975412523, Acc 0.8208333333333333; Test: Cost 1.9478941947563302, Acc 0.9. Time 0.0799107551574707
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 382/500, Train size 1200, Test size 100......
# Training at Epoch 382/500, Batch 1, Cost 1.9508253924714387, Acc 0.8225. Time 0.07295083999633789
# Epoch 382/500, Train: Cost 1.9508253924714387, Acc 0.8225; Test: Cost 1.947661029265443, Acc 0.88. Time 0.07884502410888672
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 383/500, Train size 1200, Test size 100......
# Training at Epoch 383/500, Batch 1, Cost 1.9508010018344049, Acc 0.8216666666666667. Time 0.07259917259216309
# Epoch 383/500, Train: Cost 1.9508010018344049, Acc 0.8216666666666667; Test: Cost 1.9477487894822316, Acc 0.9. Time 0.07826662063598633
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 384/500, Train size 1200, Test size 100......
# Training at Epoch 384/500, Batch 1, Cost 1.9507774958117334, Acc 0.825. Time 0.07282328605651855
# Epoch 384/500, Train: Cost 1.9507774958117334, Acc 0.825; Test: Cost 1.947686863607524, Acc 0.9. Time 0.07884860038757324
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 385/500, Train size 1200, Test size 100......
# Training at Epoch 385/500, Batch 1, Cost 1.9507566165541537, Acc 0.82. Time 0.07332849502563477
# Epoch 385/500, Train: Cost 1.9507566165541537, Acc 0.82; Test: Cost 1.947587330131142, Acc 0.88. Time 0.07924294471740723
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 386/500, Train size 1200, Test size 100......
# Training at Epoch 386/500, Batch 1, Cost 1.9507361713597402, Acc 0.8225. Time 0.07368826866149902
# Epoch 386/500, Train: Cost 1.9507361713597402, Acc 0.8225; Test: Cost 1.9476742275659045, Acc 0.91. Time 0.08043551445007324
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 387/500, Train size 1200, Test size 100......
# Training at Epoch 387/500, Batch 1, Cost 1.9507124719189837, Acc 0.82. Time 0.07335138320922852
# Epoch 387/500, Train: Cost 1.9507124719189837, Acc 0.82; Test: Cost 1.9474921013381203, Acc 0.9. Time 0.07965373992919922
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 388/500, Train size 1200, Test size 100......
# Training at Epoch 388/500, Batch 1, Cost 1.9506839211450182, Acc 0.8233333333333334. Time 0.07291603088378906
# Epoch 388/500, Train: Cost 1.9506839211450182, Acc 0.8233333333333334; Test: Cost 1.9475423187710073, Acc 0.91. Time 0.07883071899414062
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 389/500, Train size 1200, Test size 100......
# Training at Epoch 389/500, Batch 1, Cost 1.950652960532669, Acc 0.8216666666666667. Time 0.07285475730895996
# Epoch 389/500, Train: Cost 1.950652960532669, Acc 0.8216666666666667; Test: Cost 1.9474578795112911, Acc 0.91. Time 0.07926106452941895
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 390/500, Train size 1200, Test size 100......
# Training at Epoch 390/500, Batch 1, Cost 1.950622638144001, Acc 0.8225. Time 0.07329654693603516
# Epoch 390/500, Train: Cost 1.950622638144001, Acc 0.8225; Test: Cost 1.9473775176080035, Acc 0.91. Time 0.0795433521270752
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 391/500, Train size 1200, Test size 100......
# Training at Epoch 391/500, Batch 1, Cost 1.9505941212013418, Acc 0.8225. Time 0.07355117797851562
# Epoch 391/500, Train: Cost 1.9505941212013418, Acc 0.8225; Test: Cost 1.9474244871243678, Acc 0.91. Time 0.07999277114868164
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 392/500, Train size 1200, Test size 100......
# Training at Epoch 392/500, Batch 1, Cost 1.9505659314650425, Acc 0.82. Time 0.0728919506072998
# Epoch 392/500, Train: Cost 1.9505659314650425, Acc 0.82; Test: Cost 1.9472620417435502, Acc 0.91. Time 0.07935309410095215
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 393/500, Train size 1200, Test size 100......
# Training at Epoch 393/500, Batch 1, Cost 1.9505358613432189, Acc 0.8225. Time 0.07271337509155273
# Epoch 393/500, Train: Cost 1.9505358613432189, Acc 0.8225; Test: Cost 1.9473098751828781, Acc 0.91. Time 0.07902121543884277
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 394/500, Train size 1200, Test size 100......
# Training at Epoch 394/500, Batch 1, Cost 1.9505034866107682, Acc 0.8216666666666667. Time 0.07365822792053223
# Epoch 394/500, Train: Cost 1.9505034866107682, Acc 0.8216666666666667; Test: Cost 1.9472062296976722, Acc 0.9. Time 0.07986021041870117
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 395/500, Train size 1200, Test size 100......
# Training at Epoch 395/500, Batch 1, Cost 1.9504696091132367, Acc 0.8216666666666667. Time 0.07378220558166504
# Epoch 395/500, Train: Cost 1.9504696091132367, Acc 0.8216666666666667; Test: Cost 1.9471432336085273, Acc 0.91. Time 0.08082151412963867
# ...
# Training at Epoch 453/500, Batch 1, Cost 1.9502743468245014, Acc 0.8625. Time 0.0744483470916748
# Epoch 453/500, Train: Cost 1.9502743468245014, Acc 0.8625; Test: Cost 1.937160120448428, Acc 0.9. Time 0.08043146133422852
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 454/500, Train size 1200, Test size 100......
# Training at Epoch 454/500, Batch 1, Cost 1.9503429908547008, Acc 0.84. Time 0.07363724708557129
# Epoch 454/500, Train: Cost 1.9503429908547008, Acc 0.84; Test: Cost 1.9368070918370859, Acc 0.87. Time 0.07970142364501953
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 455/500, Train size 1200, Test size 100......
# Training at Epoch 455/500, Batch 1, Cost 1.9504931600690627, Acc 0.865. Time 0.07309103012084961
# Epoch 455/500, Train: Cost 1.9504931600690627, Acc 0.865; Test: Cost 1.9375194817918264, Acc 0.91. Time 0.0788869857788086
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 456/500, Train size 1200, Test size 100......
# Training at Epoch 456/500, Batch 1, Cost 1.9504844792586213, Acc 0.8475. Time 0.07247352600097656
# Epoch 456/500, Train: Cost 1.9504844792586213, Acc 0.8475; Test: Cost 1.9366813239085952, Acc 0.87. Time 0.07814311981201172
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 457/500, Train size 1200, Test size 100......
# Training at Epoch 457/500, Batch 1, Cost 1.9503377214870832, Acc 0.8575. Time 0.07325553894042969
# Epoch 457/500, Train: Cost 1.9503377214870832, Acc 0.8575; Test: Cost 1.9369332095598624, Acc 0.88. Time 0.07920169830322266
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 458/500, Train size 1200, Test size 100......
# Training at Epoch 458/500, Batch 1, Cost 1.9502560177739365, Acc 0.865. Time 0.07381319999694824
# Epoch 458/500, Train: Cost 1.9502560177739365, Acc 0.865; Test: Cost 1.936983097624003, Acc 0.9. Time 0.0800936222076416
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 459/500, Train size 1200, Test size 100......
# Training at Epoch 459/500, Batch 1, Cost 1.950318916323548, Acc 0.8433333333333334. Time 0.07309389114379883
# Epoch 459/500, Train: Cost 1.950318916323548, Acc 0.8433333333333334; Test: Cost 1.9368853814781266, Acc 0.87. Time 0.07910919189453125
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 460/500, Train size 1200, Test size 100......
# Training at Epoch 460/500, Batch 1, Cost 1.9503978501660164, Acc 0.8658333333333333. Time 0.07278871536254883
# Epoch 460/500, Train: Cost 1.9503978501660164, Acc 0.8658333333333333; Test: Cost 1.9371864709113757, Acc 0.91. Time 0.0792837142944336
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 461/500, Train size 1200, Test size 100......
# Training at Epoch 461/500, Batch 1, Cost 1.9503667635293973, Acc 0.8508333333333333. Time 0.0726628303527832
# Epoch 461/500, Train: Cost 1.9503667635293973, Acc 0.8508333333333333; Test: Cost 1.9367644349465485, Acc 0.88. Time 0.07885050773620605
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 462/500, Train size 1200, Test size 100......
# Training at Epoch 462/500, Batch 1, Cost 1.9502736283714577, Acc 0.8558333333333333. Time 0.07397198677062988
# Epoch 462/500, Train: Cost 1.9502736283714577, Acc 0.8558333333333333; Test: Cost 1.9368919100011608, Acc 0.88. Time 0.08020782470703125
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 463/500, Train size 1200, Test size 100......
# Training at Epoch 463/500, Batch 1, Cost 1.9502388994336284, Acc 0.8641666666666666. Time 0.07341265678405762
# Epoch 463/500, Train: Cost 1.9502388994336284, Acc 0.8641666666666666; Test: Cost 1.936923385914297, Acc 0.9. Time 0.08057141304016113
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 464/500, Train size 1200, Test size 100......
# Training at Epoch 464/500, Batch 1, Cost 1.9502853623009326, Acc 0.8466666666666667. Time 0.07323431968688965
# Epoch 464/500, Train: Cost 1.9502853623009326, Acc 0.8466666666666667; Test: Cost 1.9368288124994235, Acc 0.87. Time 0.07937788963317871
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 465/500, Train size 1200, Test size 100......
# Training at Epoch 465/500, Batch 1, Cost 1.9503263712752301, Acc 0.8641666666666666. Time 0.07343888282775879
# Epoch 465/500, Train: Cost 1.9503263712752301, Acc 0.8641666666666666; Test: Cost 1.9369172328429574, Acc 0.9. Time 0.07974004745483398
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 466/500, Train size 1200, Test size 100......
# Training at Epoch 466/500, Batch 1, Cost 1.9502980808098893, Acc 0.8541666666666666. Time 0.07340860366821289
# Epoch 466/500, Train: Cost 1.9502980808098893, Acc 0.8541666666666666; Test: Cost 1.9367394132634752, Acc 0.88. Time 0.0805659294128418
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 467/500, Train size 1200, Test size 100......
# Training at Epoch 467/500, Batch 1, Cost 1.9502401560718947, Acc 0.855. Time 0.07560300827026367
# Epoch 467/500, Train: Cost 1.9502401560718947, Acc 0.855; Test: Cost 1.9366813375879182, Acc 0.88. Time 0.08207917213439941
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 468/500, Train size 1200, Test size 100......
# Training at Epoch 468/500, Batch 1, Cost 1.9502222217022103, Acc 0.8633333333333333. Time 0.07381272315979004
# Epoch 468/500, Train: Cost 1.9502222217022103, Acc 0.8633333333333333; Test: Cost 1.9368533936238488, Acc 0.89. Time 0.08016514778137207
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 469/500, Train size 1200, Test size 100......
# Training at Epoch 469/500, Batch 1, Cost 1.9502505142627158, Acc 0.8491666666666666. Time 0.07328176498413086
# Epoch 469/500, Train: Cost 1.9502505142627158, Acc 0.8491666666666666; Test: Cost 1.9367053027369423, Acc 0.88. Time 0.07930445671081543
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 470/500, Train size 1200, Test size 100......
# Training at Epoch 470/500, Batch 1, Cost 1.9502723259120052, Acc 0.8633333333333333. Time 0.07327532768249512
# Epoch 470/500, Train: Cost 1.9502723259120052, Acc 0.8633333333333333; Test: Cost 1.936851300615586, Acc 0.9. Time 0.07971620559692383
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 471/500, Train size 1200, Test size 100......
# Training at Epoch 471/500, Batch 1, Cost 1.9502533072235588, Acc 0.8533333333333334. Time 0.07321047782897949
# Epoch 471/500, Train: Cost 1.9502533072235588, Acc 0.8533333333333334; Test: Cost 1.936693854938834, Acc 0.88. Time 0.07899594306945801
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 472/500, Train size 1200, Test size 100......
# Training at Epoch 472/500, Batch 1, Cost 1.9502175130748038, Acc 0.855. Time 0.07292985916137695
# Epoch 472/500, Train: Cost 1.9502175130748038, Acc 0.855; Test: Cost 1.9366576149539791, Acc 0.88. Time 0.07886791229248047
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 473/500, Train size 1200, Test size 100......
# Training at Epoch 473/500, Batch 1, Cost 1.950204914267554, Acc 0.8633333333333333. Time 0.07433748245239258
# Epoch 473/500, Train: Cost 1.950204914267554, Acc 0.8633333333333333; Test: Cost 1.9367887244151418, Acc 0.89. Time 0.08031558990478516
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 474/500, Train size 1200, Test size 100......
# Training at Epoch 474/500, Batch 1, Cost 1.9502198133556508, Acc 0.8508333333333333. Time 0.07363343238830566
# Epoch 474/500, Train: Cost 1.9502198133556508, Acc 0.8508333333333333; Test: Cost 1.9366034791452358, Acc 0.88. Time 0.07958412170410156
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 475/500, Train size 1200, Test size 100......
# Training at Epoch 475/500, Batch 1, Cost 1.9502328876147916, Acc 0.8633333333333333. Time 0.07377862930297852
# Epoch 475/500, Train: Cost 1.9502328876147916, Acc 0.8633333333333333; Test: Cost 1.9367893557504006, Acc 0.89. Time 0.08054518699645996
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 476/500, Train size 1200, Test size 100......
# Training at Epoch 476/500, Batch 1, Cost 1.9502228234978545, Acc 0.8533333333333334. Time 0.07255291938781738
# Epoch 476/500, Train: Cost 1.9502228234978545, Acc 0.8533333333333334; Test: Cost 1.9365877837741465, Acc 0.88. Time 0.07840681076049805
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 477/500, Train size 1200, Test size 100......
# Training at Epoch 477/500, Batch 1, Cost 1.950200120825399, Acc 0.8566666666666667. Time 0.0736691951751709
# Epoch 477/500, Train: Cost 1.950200120825399, Acc 0.8566666666666667; Test: Cost 1.9366625830272528, Acc 0.88. Time 0.08006095886230469
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 478/500, Train size 1200, Test size 100......
# Training at Epoch 478/500, Batch 1, Cost 1.9501879608164034, Acc 0.8608333333333333. Time 0.07382440567016602
# Epoch 478/500, Train: Cost 1.9501879608164034, Acc 0.8608333333333333; Test: Cost 1.936648727364279, Acc 0.89. Time 0.07975339889526367
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 479/500, Train size 1200, Test size 100......
# Training at Epoch 479/500, Batch 1, Cost 1.9501929920352101, Acc 0.8525. Time 0.07315802574157715
# Epoch 479/500, Train: Cost 1.9501929920352101, Acc 0.8525; Test: Cost 1.9365859069416769, Acc 0.88. Time 0.07918620109558105
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 480/500, Train size 1200, Test size 100......
# Training at Epoch 480/500, Batch 1, Cost 1.950201077330559, Acc 0.8625. Time 0.07279062271118164
# Epoch 480/500, Train: Cost 1.950201077330559, Acc 0.8625; Test: Cost 1.9366570154290441, Acc 0.89. Time 0.07847833633422852
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 481/500, Train size 1200, Test size 100......
# Training at Epoch 481/500, Batch 1, Cost 1.9501974870323193, Acc 0.8508333333333333. Time 0.0724785327911377
# Epoch 481/500, Train: Cost 1.9501974870323193, Acc 0.8508333333333333; Test: Cost 1.9365389388236107, Acc 0.88. Time 0.07840657234191895
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 482/500, Train size 1200, Test size 100......
# Training at Epoch 482/500, Batch 1, Cost 1.9501837641058377, Acc 0.8583333333333333. Time 0.07340288162231445
# Epoch 482/500, Train: Cost 1.9501837641058377, Acc 0.8583333333333333; Test: Cost 1.9365950621517687, Acc 0.88. Time 0.0797877311706543
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 483/500, Train size 1200, Test size 100......
# Training at Epoch 483/500, Batch 1, Cost 1.9501722356859508, Acc 0.8591666666666666. Time 0.07372140884399414
# Epoch 483/500, Train: Cost 1.9501722356859508, Acc 0.8591666666666666; Test: Cost 1.9365541319783535, Acc 0.88. Time 0.08030891418457031
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 484/500, Train size 1200, Test size 100......
# Training at Epoch 484/500, Batch 1, Cost 1.950170533443164, Acc 0.8541666666666666. Time 0.0731210708618164
# Epoch 484/500, Train: Cost 1.950170533443164, Acc 0.8541666666666666; Test: Cost 1.936543057086634, Acc 0.88. Time 0.07912302017211914
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 485/500, Train size 1200, Test size 100......
# Training at Epoch 485/500, Batch 1, Cost 1.9501743562470681, Acc 0.8608333333333333. Time 0.07351207733154297
# Epoch 485/500, Train: Cost 1.9501743562470681, Acc 0.8608333333333333; Test: Cost 1.9365543105859149, Acc 0.89. Time 0.07927250862121582
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 486/500, Train size 1200, Test size 100......
# Training at Epoch 486/500, Batch 1, Cost 1.9501744543354775, Acc 0.8533333333333334. Time 0.07358312606811523
# Epoch 486/500, Train: Cost 1.9501744543354775, Acc 0.8533333333333334; Test: Cost 1.9365170617585685, Acc 0.88. Time 0.07964777946472168
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 487/500, Train size 1200, Test size 100......
# Training at Epoch 487/500, Batch 1, Cost 1.950167433932229, Acc 0.8591666666666666. Time 0.07373857498168945
# Epoch 487/500, Train: Cost 1.950167433932229, Acc 0.8591666666666666; Test: Cost 1.9365064701323564, Acc 0.88. Time 0.08033013343811035
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 488/500, Train size 1200, Test size 100......
# Training at Epoch 488/500, Batch 1, Cost 1.9501577862470922, Acc 0.8575. Time 0.07317447662353516
# Epoch 488/500, Train: Cost 1.9501577862470922, Acc 0.8575; Test: Cost 1.9365130012519618, Acc 0.88. Time 0.07891345024108887
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 489/500, Train size 1200, Test size 100......
# Training at Epoch 489/500, Batch 1, Cost 1.950151824908483, Acc 0.8541666666666666. Time 0.07253766059875488
# Epoch 489/500, Train: Cost 1.950151824908483, Acc 0.8541666666666666; Test: Cost 1.9364521071880234, Acc 0.88. Time 0.07829117774963379
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 490/500, Train size 1200, Test size 100......
# Training at Epoch 490/500, Batch 1, Cost 1.950150922328619, Acc 0.86. Time 0.07264471054077148
# Epoch 490/500, Train: Cost 1.950150922328619, Acc 0.86; Test: Cost 1.9365135557018411, Acc 0.89. Time 0.07840871810913086
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 491/500, Train size 1200, Test size 100......
# Training at Epoch 491/500, Batch 1, Cost 1.950151289372944, Acc 0.8533333333333334. Time 0.07230544090270996
# Epoch 491/500, Train: Cost 1.950151289372944, Acc 0.8533333333333334; Test: Cost 1.9364245651619554, Acc 0.88. Time 0.07816815376281738
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 492/500, Train size 1200, Test size 100......
# Training at Epoch 492/500, Batch 1, Cost 1.9501487120241803, Acc 0.8608333333333333. Time 0.07460951805114746
# Epoch 492/500, Train: Cost 1.9501487120241803, Acc 0.8608333333333333; Test: Cost 1.936479308965272, Acc 0.89. Time 0.08164453506469727
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 493/500, Train size 1200, Test size 100......
# Training at Epoch 493/500, Batch 1, Cost 1.9501425807709603, Acc 0.8541666666666666. Time 0.07321858406066895
# Epoch 493/500, Train: Cost 1.9501425807709603, Acc 0.8541666666666666; Test: Cost 1.9364154646620648, Acc 0.88. Time 0.07936215400695801
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 494/500, Train size 1200, Test size 100......
# Training at Epoch 494/500, Batch 1, Cost 1.9501357737075042, Acc 0.855. Time 0.07300639152526855
# Epoch 494/500, Train: Cost 1.9501357737075042, Acc 0.855; Test: Cost 1.9364303530338722, Acc 0.88. Time 0.07997274398803711
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 495/500, Train size 1200, Test size 100......
# Training at Epoch 495/500, Batch 1, Cost 1.95013113597162, Acc 0.8583333333333333. Time 0.07331991195678711
# Epoch 495/500, Train: Cost 1.95013113597162, Acc 0.8583333333333333; Test: Cost 1.9364236673508526, Acc 0.88. Time 0.07937192916870117
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 496/500, Train size 1200, Test size 100......
# Training at Epoch 496/500, Batch 1, Cost 1.9501289994564284, Acc 0.8541666666666666. Time 0.07375216484069824
# Epoch 496/500, Train: Cost 1.9501289994564284, Acc 0.8541666666666666; Test: Cost 1.9363916850806218, Acc 0.88. Time 0.07965540885925293
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 497/500, Train size 1200, Test size 100......
# Training at Epoch 497/500, Batch 1, Cost 1.9501274169075526, Acc 0.8608333333333333. Time 0.0732886791229248
# Epoch 497/500, Train: Cost 1.9501274169075526, Acc 0.8608333333333333; Test: Cost 1.9364131450079338, Acc 0.88. Time 0.07937288284301758
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 498/500, Train size 1200, Test size 100......
# Training at Epoch 498/500, Batch 1, Cost 1.9501243315964638, Acc 0.855. Time 0.07327604293823242
# Epoch 498/500, Train: Cost 1.9501243315964638, Acc 0.855; Test: Cost 1.9363642251756383, Acc 0.88. Time 0.08000469207763672
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 499/500, Train size 1200, Test size 100......
# Training at Epoch 499/500, Batch 1, Cost 1.95011940241477, Acc 0.8591666666666666. Time 0.07317018508911133
# Epoch 499/500, Train: Cost 1.95011940241477, Acc 0.8591666666666666; Test: Cost 1.9363789873358697, Acc 0.88. Time 0.07893538475036621
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 500/500, Train size 1200, Test size 100......
# Training at Epoch 500/500, Batch 1, Cost 1.9501138276945313, Acc 0.8591666666666666. Time 0.07347297668457031
# Epoch 500/500, Train: Cost 1.9501138276945313, Acc 0.8591666666666666; Test: Cost 1.9363432602359194, Acc 0.88. Time 0.07938122749328613
# =-==-==-==-==-==-==-==-==-==-=

# %%
# aggregate dataframe
df_agg = results_df.groupby(["n_train", "step"]).agg(["mean", "std"])
df_agg = df_agg.reset_index()

sns.set_style('whitegrid')
colors = sns.color_palette()
fig, axes = plt.subplots(ncols=2, figsize=(24, 7))

generalization_errors = []

# plot losses and accuracies
for i, n_train in enumerate(train_sizes):
    df = df_agg[df_agg.n_train == n_train]

    dfs = [df.train_cost["mean"], df.test_cost["mean"], df.train_acc["mean"], df.test_acc["mean"]]
    lines = ["o-", "x--", "o-", "x--"]
    labels = [fr"$N={n_train}$", None, fr"$N={n_train}$", None]
    axs = [0,0,1,1]

    for k in range(4):
        ax = axes[axs[k]]
        ax.plot(df.step, dfs[k], lines[k], label=labels[k], markevery=10, color=colors[i], alpha=0.8)


    # plot final loss difference
    #dif = df[df.step == n_epochs].test_cost["mean"] - df[df.step == n_epochs].train_cost["mean"]
    #generalization_errors.append(dif)

# format loss plot
ax = axes[0]
ax.set_title('Train and Test Losses', fontsize=14)
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')

# format generalization error plot
#ax = axes[1]
#ax.plot(train_sizes, generalization_errors, "o-", label=r"$gen(\alpha)$")
#ax.set_xscale('log')
#ax.set_xticks(train_sizes)
#ax.set_xticklabels(train_sizes)
#ax.set_title(r'Generalization Error $gen(\alpha) = R(\alpha) - \hat{R}_N(\alpha)$', fontsize=14)
#ax.set_xlabel('Training Set Size')

# format loss plot
ax = axes[1]
ax.set_title('Train and Test Accuracies', fontsize=14)
ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy')
ax.set_ylim(0.05, 1.05)

legend_elements = [
    mpl.lines.Line2D([0], [0], label=f'N={n}', color=colors[i]) for i, n in enumerate(train_sizes)
    ] + [
    mpl.lines.Line2D([0], [0], marker='o', ls='-', label='Train', color='Black'),
    mpl.lines.Line2D([0], [0], marker='x', ls='--', label='Test', color='Black')
    ]

axes[0].legend(handles=legend_elements, ncol=3)
axes[1].legend(handles=legend_elements, ncol=3)

#axes[1].set_yscale('log', base=2)
plt.show()

# %%
save_folder = "/content/drive/MyDrive/Research/HermtianEncodingImg/sklearn-digits-dataset"
results_df.to_csv(os.path.join(save_folder, "digits_baseline_results.csv"))
df_agg.to_csv(os.path.join(save_folder, "digits_baseline_results_agg.csv"))
# save the plot to file
fig.savefig(os.path.join(save_folder, "digits_baseline_results.png"))
